# %% [markdown]
# <a href="https://colab.research.google.com/github/doyeo-n/-Capstone-8_code/blob/main/%5B8%5D%EC%95%84%EB%91%90%EC%9D%B4%EB%85%B8_%EC%BB%B4%ED%8C%8C%EC%9D%BC_%EC%BD%94%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int red = 9;
int green = 10;
int blue = 11;
int input_data;

void setup() {
  Serial.begin(9600);
  pinMode(red, OUTPUT);
  pinMode(green, OUTPUT);
  pinMode(blue, OUTPUT);
}

void loop() {
  // put your main code here, to run repeatedly:

  while(Serial.available()){
    input_data = Serial.read();
  }

  if(input_data == '3'){
    digitalWrite(9, HIGH); //red on
    digitalWrite(10, LOW);
    digitalWrite(11, LOW);
  }
  else if(input_data == '2'){
    digitalWrite(10, HIGH); //green on
    digitalWrite(9, LOW);
    digitalWrite(11, LOW);
  }
  else if(input_data == '1'){
    digitalWrite(11, HIGH); //blue on
    digitalWrite(9, LOW);
    digitalWrite(10, LOW);
  }
  else if(input_data == '0'){
    digitalWrite(9,LOW);
    digitalWrite(10,LOW);
    digitalWrite(11,LOW);
  }
}
